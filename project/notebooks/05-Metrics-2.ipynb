# %%
import pandas as pd
import json
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# adapters_bert_df = pd.read_csv("../outputs/adapters_bert_bleu.csv")
# adapters_bert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
# adapters_bert_df["name"] = "adapters_bert"

baseline_bert_df = pd.read_csv("../outputs/baseline_bert.csv")
baseline_bert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
baseline_bert_df["name"] = "baseline_bert"

bert_adapter_bert_df = pd.read_csv("../outputs/bert_adapter_bert_bleu.csv")
bert_adapter_bert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
bert_adapter_bert_df["name"] = "bert_adapter_bert"

adapter_bert_bert_df = pd.read_csv("../outputs/adapter_bert_bert_bleu.csv")
adapter_bert_bert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
adapter_bert_bert_df["name"] = "adapter_bert_bert"

tmp_adapters_bert_df = pd.read_csv("../outputs/adapters_bert_bleu.csv")
bert_8_df = tmp_adapters_bert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_bert_red8 - eval/bleu"]]
bert_8_df.columns = ["steps", "bleu"]
bert_8_df["name"] = "adapt_bert_reduc_8"
bert_4_df = tmp_adapters_bert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_bert_red4 - eval/bleu"]]
bert_4_df.columns = ["steps", "bleu"]
bert_4_df["name"] = "adapt_bert_reduc_4"
bert_2_df = tmp_adapters_bert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_bert_red2 - eval/bleu"]]
bert_2_df.columns = ["steps", "bleu"]
bert_2_df["name"] = "adapt_bert_reduc_2"
bert_1_df = tmp_adapters_bert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_bert_red1 - eval/bleu"]]
bert_1_df.columns = ["steps", "bleu"]
bert_1_df["name"] = "adapt_bert_reduc_1"
bert_16_df = tmp_adapters_bert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_de_en_bert - eval/bleu"]]
bert_16_df.columns = ["steps", "bleu"]
bert_16_df["name"] = "adapt_bert_reduc_16"
adapters_bert_df = pd.concat([bert_16_df, bert_8_df, bert_4_df, bert_2_df, bert_1_df])

tmp_adapters_zbert_df = pd.read_csv("../outputs/adapters_zbert_bleu.csv")
zbert_8_df = tmp_adapters_zbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zbert_8_reduction - eval/bleu"]]
zbert_8_df.columns = ["steps", "bleu"]
zbert_8_df["name"] = "adapt_zbert_reduc_8"
zbert_4_df = tmp_adapters_zbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zbert_4_reduction - eval/bleu"]]
zbert_4_df.columns = ["steps", "bleu"]
zbert_4_df["name"] = "adapt_zbert_reduc_4"
zbert_2_df = tmp_adapters_zbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zbert_2_reduction - eval/bleu"]]
zbert_2_df.columns = ["steps", "bleu"]
zbert_2_df["name"] = "adapt_zbert_reduc_2"
zbert_1_df = tmp_adapters_zbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zbert_1_reduction - eval/bleu"]]
zbert_1_df.columns = ["steps", "bleu"]
zbert_1_df["name"] = "adapt_zbert_reduc_1"
zbert_16_df = tmp_adapters_zbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zbert - eval/bleu"]]
zbert_16_df.columns = ["steps", "bleu"]
zbert_16_df["name"] = "adapt_zbert_reduc_16"
adapters_zbert_df = pd.concat([zbert_16_df, zbert_8_df, zbert_4_df, zbert_2_df, zbert_1_df])

adapter_zbert_zbert_df = pd.read_csv("../outputs/adapter_zbert_zbert_bleu.csv")
adapter_zbert_zbert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
adapter_zbert_zbert_df["name"] = "adapter_zbert_zbert"

zbert_adapter_zbert_df = pd.read_csv("../outputs/zbert_adapter_zbert_bleu.csv")
zbert_adapter_zbert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
zbert_adapter_zbert_df["name"] = "zbert_adapter_zbert"

tmp_adapters_zsbert_df = pd.read_csv("../outputs/adapters_zsbert_bleu.csv")
zsbert_8_df = tmp_adapters_zsbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zsbert_8_reduction - eval/bleu"]]
zsbert_8_df.columns = ["steps", "bleu"]
zsbert_8_df["name"] = "adapt_zsbert_reduc_8"
zsbert_4_df = tmp_adapters_zsbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zsbert_4_reduction - eval/bleu"]]
zsbert_4_df.columns = ["steps", "bleu"]
zsbert_4_df["name"] = "adapt_zsbert_reduc_4"
zsbert_2_df = tmp_adapters_zsbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zsbert_2_reduction - eval/bleu"]]
zsbert_2_df.columns = ["steps", "bleu"]
zsbert_2_df["name"] = "adapt_zsbert_reduc_2"
zsbert_1_df = tmp_adapters_zsbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zsbert_1_reduction - eval/bleu"]]
zsbert_1_df.columns = ["steps", "bleu"]
zsbert_1_df["name"] = "adapt_zsbert_reduc_1"
zsbert_16_df = tmp_adapters_zsbert_df[["Step", "/storage/brno3-cerit/home/akurniawan/adapters-project/outputs/adapters_zsbert - eval/bleu"]]
zsbert_16_df.columns = ["steps", "bleu"]
zsbert_16_df["name"] = "adapt_zsbert_reduc_16"
adapters_zsbert_df = pd.concat([zsbert_16_df, zsbert_8_df, zsbert_4_df, zsbert_2_df, zsbert_1_df])

adapter_zsbert_zsbert_df = pd.read_csv("../outputs/adapter_zsbert_zsbert_bleu.csv")
adapter_zsbert_zsbert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
adapter_zsbert_zsbert_df["name"] = "adapter_zsbert_zsbert"

zsbert_adapter_zsbert_df = pd.read_csv("../outputs/zsbert_adapter_zsbert_bleu.csv")
zsbert_adapter_zsbert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
zsbert_adapter_zsbert_df["name"] = "zsbert_adapter_zsbert"

baseline_zbert_df = pd.read_csv("../outputs/baseline_zbert_bleu.csv")
baseline_zbert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
baseline_zbert_df["name"] = "baseline_zbert"

baseline_zsbert_df = pd.read_csv("../outputs/baseline_zsbert_bleu.csv")
baseline_zsbert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
baseline_zsbert_df["name"] = "baseline_zsbert"

bert_adapter_randdec_df = pd.read_csv("../outputs/bert_adapter_randdec_bleu.csv")
bert_adapter_randdec_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
bert_adapter_randdec_df["name"] = "bert_adapter_randdec"

adapter_bert_randdec_df = pd.read_csv("../outputs/adapter_bert_randdec_bleu.csv")
adapter_bert_randdec_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
adapter_bert_randdec_df["name"] = "adapter_bert_randdec"

adapter_bert_adapter_randdec_df = pd.read_csv("../outputs/adapter_bert_adapter_randdec_bleu.csv")
adapter_bert_adapter_randdec_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
adapter_bert_adapter_randdec_df["name"] = "adapter_bert_adapter_randdec"

randenc_adapter_bert_df = pd.read_csv("../outputs/randenc_adapter_bert_bleu.csv")
randenc_adapter_bert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
randenc_adapter_bert_df["name"] = "randenc_adapter_bert"

adapter_randenc_bert_df = pd.read_csv("../outputs/adapter_randenc_bert_bleu.csv")
adapter_randenc_bert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
adapter_randenc_bert_df["name"] = "adapter_randenc_bert"

adapter_randenc_adapter_bert_df = pd.read_csv("../outputs/adapter_randenc_adapter_bert_bleu.csv")
adapter_randenc_adapter_bert_df.columns = ["steps", "bleu", "min_bleu", "max_bleu"]
adapter_randenc_adapter_bert_df["name"] = "adapter_randenc_adapter_bert"
# Out:
# /var/folders/7x/9jh7pmld61sf567fnd5q02_r0000gn/T/ipykernel_17635/1380185401.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bert_8_df["name"] = "adapt_bert_reduc_8"
# /var/folders/7x/9jh7pmld61sf567fnd5q02_r0000gn/T/ipykernel_17635/1380185401.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bert_4_df["name"] = "adapt_bert_reduc_4"
# /var/folders/7x/9jh7pmld61sf567fnd5q02_r0000gn/T/ipykernel_17635/1380185401.py:26: SettingWithCopyWarning:
# ...

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
comb_df = pd.concat([baseline_bert_df], ignore_index=True)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")

# %%
# comb_df["name"].unique(), len(comb_df)
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
fin_adapters_bert_df = adapters_bert_df[adapters_bert_df["steps"] < 500]
comb_df = pd.concat([baseline_bert_df, fin_adapters_bert_df], ignore_index=True)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])
handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [1, 2, 3, 4, 5, 0]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
# Out:
# ['baseline_bert', 'adapt_bert_reduc_16', 'adapt_bert_reduc_8', 'adapt_bert_reduc_4', 'adapt_bert_reduc_2', 'adapt_bert_reduc_1']
# ['adapt_bert_reduc_16', 'adapt_bert_reduc_8', 'adapt_bert_reduc_4', 'adapt_bert_reduc_2', 'adapt_bert_reduc_1', 'baseline_bert']

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
adapter_bert_bert_df = adapter_bert_bert_df[adapter_bert_bert_df["steps"] < 500]
bert_adapter_bert_df = bert_adapter_bert_df[bert_adapter_bert_df["steps"] < 500]
fin_adapters_bert_df = adapters_bert_df[(adapters_bert_df["steps"] < 500) & (adapters_bert_df["name"] == "adapt_bert_reduc_16")]
comb_df = pd.concat([baseline_bert_df, fin_adapters_bert_df, adapter_bert_bert_df, bert_adapter_bert_df], ignore_index=True)
# comb_df["name"].unique(), len(comb_df)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])
handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [2, 1, 3, 0]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
# Out:
# ['baseline_bert', 'adapt_bert_reduc_16', 'adapter_bert_bert', 'bert_adapter_bert']

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
adapter_bert_bert_df = adapter_bert_bert_df[adapter_bert_bert_df["steps"] < 500]
adapter_randenc_adapter_bert_df = adapter_randenc_adapter_bert_df[adapter_randenc_adapter_bert_df["steps"] < 500]
adapter_randenc_bert_df = adapter_randenc_bert_df[adapter_randenc_bert_df["steps"] < 500]
randenc_adapter_bert_df = randenc_adapter_bert_df[randenc_adapter_bert_df["steps"] < 500]
fin_adapters_bert_df = adapters_bert_df[(adapters_bert_df["steps"] < 500) & (adapters_bert_df["name"] == "adapt_bert_reduc_16")]
comb_df = pd.concat([baseline_bert_df, fin_adapters_bert_df, adapter_randenc_adapter_bert_df, adapter_randenc_bert_df, randenc_adapter_bert_df], ignore_index=True)
# comb_df["name"].unique(), len(comb_df)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_700k", "adapters_pt"])
handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [1, 0, 2, 3, 4]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# ['baseline_bert', 'adapt_bert_reduc_16', 'adapter_randenc_adapter_bert', 'adapter_randenc_bert', 'randenc_adapter_bert']

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
adapter_bert_bert_df = adapter_bert_bert_df[adapter_bert_bert_df["steps"] < 500]
adapter_bert_adapter_randdec_df = adapter_bert_adapter_randdec_df[adapter_bert_adapter_randdec_df["steps"] < 500]
adapter_bert_randdec_df = adapter_bert_randdec_df[adapter_bert_randdec_df["steps"] < 500]
bert_adapter_randdec_df = bert_adapter_randdec_df[bert_adapter_randdec_df["steps"] < 500]
fin_adapters_bert_df = adapters_bert_df[(adapters_bert_df["steps"] < 500) & (adapters_bert_df["name"] == "adapt_bert_reduc_16")]
comb_df = pd.concat([baseline_bert_df, fin_adapters_bert_df, adapter_bert_adapter_randdec_df, adapter_bert_randdec_df, bert_adapter_randdec_df], ignore_index=True)
# comb_df["name"].unique(), len(comb_df)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")

handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [1, 0, 2, 3, 4]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# ['baseline_bert', 'adapt_bert_reduc_16', 'adapter_bert_adapter_randdec', 'adapter_bert_randdec', 'bert_adapter_randdec']

# %%
adapter_bert_adapter_randdec_df
# Out:
#      steps      bleu  min_bleu  max_bleu                          name
# 0        4  16.38260    8.2822   24.4830  adapter_bert_adapter_randdec
# 1        9  18.04880   11.3604   24.7372  adapter_bert_adapter_randdec
# 2       14  18.86280   13.3221   24.4035  adapter_bert_adapter_randdec
# 3       19  19.82440   15.2030   24.4458  adapter_bert_adapter_randdec
# 4       24  20.47835   16.3712   24.5855  adapter_bert_adapter_randdec
# ..     ...       ...       ...       ...                           ...
# 96     479  23.80400   23.8040   23.8040  adapter_bert_adapter_randdec
# 97     484  23.54000   23.5400   23.5400  adapter_bert_adapter_randdec
# 98     489  23.75580   23.7558   23.7558  adapter_bert_adapter_randdec
# 99     494  23.89900   23.8990   23.8990  adapter_bert_adapter_randdec
# 100    499  23.77320   23.7732   23.7732  adapter_bert_adapter_randdec
#
# [101 rows x 5 columns]

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
baseline_zbert_df = baseline_zbert_df[baseline_zbert_df["steps"] < 500]
comb_df = pd.concat([baseline_bert_df, baseline_zbert_df], ignore_index=True)
# comb_df["name"].unique(), len(comb_df)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
baseline_zbert_df = baseline_zbert_df[baseline_zbert_df["steps"] < 500]
adapters_zbert_df = adapters_zbert_df[adapters_zbert_df["steps"] < 500]
fin_adapters_zbert_df = adapters_zbert_df[adapters_zbert_df["name"] == "adapt_zbert_reduc_16"]
comb_df = pd.concat([baseline_bert_df, baseline_zbert_df, fin_adapters_zbert_df], ignore_index=True)
# comb_df["name"].unique(), len(comb_df)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [0, 2, 1]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
# Out:
# ['baseline_bert', 'baseline_zbert', 'adapt_zbert_reduc_16']

# %%
# comb_df["name"].unique(), len(comb_df)
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
fin_adapters_zbert_df = adapters_zbert_df[adapters_zbert_df["steps"] < 500]
comb_df = pd.concat([baseline_bert_df, fin_adapters_zbert_df], ignore_index=True)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
baseline_zbert_df = baseline_zbert_df[baseline_zbert_df["steps"] < 500]
baseline_zsbert_df = baseline_zsbert_df[baseline_zsbert_df["steps"] < 500]
comb_df = pd.concat([baseline_bert_df, baseline_zbert_df, baseline_zsbert_df], ignore_index=True)
# comb_df["name"].unique(), len(comb_df)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

# %%
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
baseline_zbert_df = baseline_zbert_df[baseline_zbert_df["steps"] < 500]
adapters_zbert_df = adapters_zbert_df[adapters_zbert_df["steps"] < 500]
fin_adapters_zbert_df = adapters_zbert_df[adapters_zbert_df["name"] == "adapt_zbert_reduc_16"]
adapters_zsbert_df = adapters_zsbert_df[adapters_zsbert_df["steps"] < 500]
fin_adapters_zsbert_df = adapters_zsbert_df[adapters_zsbert_df["name"] == "adapt_zsbert_reduc_16"]
comb_df = pd.concat([baseline_bert_df, baseline_zbert_df, fin_adapters_zbert_df, fin_adapters_zsbert_df], ignore_index=True)
# comb_df["name"].unique(), len(comb_df)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [0, 3, 2, 1]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
# Out:
# ['baseline_bert', 'baseline_zbert', 'adapt_zbert_reduc_16', 'adapt_zsbert_reduc_16']

# %%
# comb_df["name"].unique(), len(comb_df)
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 700]
fin_adapters_zsbert_df = adapters_zsbert_df[adapters_zsbert_df["steps"] < 700]
comb_df = pd.concat([baseline_bert_df, fin_adapters_zsbert_df], ignore_index=True)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_700k", "adapters_pt"])

handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [0, 5, 4, 3, 2, 1]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
# Out:
# ['baseline_bert', 'adapt_zsbert_reduc_16', 'adapt_zsbert_reduc_8', 'adapt_zsbert_reduc_4', 'adapt_zsbert_reduc_2', 'adapt_zsbert_reduc_1']

# %%
# comb_df["name"].unique(), len(comb_df)
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
baseline_zbert_df = baseline_zbert_df[baseline_zbert_df["steps"] < 500]
fin_adapters_zbert_df = adapters_zbert_df[adapters_zbert_df["steps"] < 500]
fin_adapters_zbert_df = fin_adapters_zbert_df[fin_adapters_zbert_df["name"] == "adapt_zbert_reduc_16"]
adapter_zbert_zbert_df = adapter_zbert_zbert_df[adapter_zbert_zbert_df["steps"] < 500]
zbert_adapter_zbert_df = zbert_adapter_zbert_df[zbert_adapter_zbert_df["steps"] < 500]
comb_df = pd.concat([baseline_bert_df, baseline_zbert_df, fin_adapters_zbert_df, adapter_zbert_zbert_df, zbert_adapter_zbert_df], ignore_index=True)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [0, 2, 3, 4, 1]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
# Out:
# ['baseline_bert', 'baseline_zbert', 'adapt_zbert_reduc_16', 'adapter_zbert_zbert', 'zbert_adapter_zbert']

# %%
# comb_df["name"].unique(), len(comb_df)
baseline_bert_df = baseline_bert_df[baseline_bert_df["steps"] < 500]
baseline_zbert_df = baseline_zbert_df[baseline_zbert_df["steps"] < 500]
baseline_zsbert_df = baseline_zsbert_df[baseline_zsbert_df["steps"] < 500]
fin_adapters_zsbert_df = adapters_zsbert_df[adapters_zsbert_df["steps"] < 500]
fin_adapters_zsbert_df = fin_adapters_zsbert_df[fin_adapters_zsbert_df["name"] == "adapt_zsbert_reduc_16"]
adapter_zsbert_zsbert_df = adapter_zsbert_zsbert_df[adapter_zsbert_zsbert_df["steps"] < 500]
zsbert_adapter_zsbert_df = zsbert_adapter_zsbert_df[zsbert_adapter_zsbert_df["steps"] < 500]
comb_df = pd.concat([baseline_bert_df, baseline_zbert_df, baseline_zsbert_df, fin_adapters_zsbert_df, adapter_zsbert_zsbert_df, zsbert_adapter_zsbert_df], ignore_index=True)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [0, 4, 3, 1, 5, 2]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# ['baseline_bert', 'baseline_zbert', 'baseline_zsbert', 'adapt_zsbert_reduc_16', 'adapter_zsbert_zsbert', 'zsbert_adapter_zsbert']

# %%
fin_adapters_zbert_df = adapters_zbert_df[adapters_zbert_df["steps"] < 500]
fin_adapters_zbert_df = fin_adapters_zbert_df[fin_adapters_zbert_df["name"] == "adapt_zbert_reduc_16"]
fin_adapters_zsbert_df = adapters_zsbert_df[adapters_zsbert_df["steps"] < 500]
fin_adapters_zsbert_df = fin_adapters_zsbert_df[fin_adapters_zsbert_df["name"] == "adapt_zsbert_reduc_16"]
comb_df = pd.concat([fin_adapters_zbert_df, fin_adapters_zsbert_df], ignore_index=True)
plt.figure(figsize=(6, 4), dpi = 100) 
ax = sns.lineplot(data=comb_df, x="steps", y="bleu", hue="name", style="name")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ax.legend(["adapters_bert", "adapters_pt_2m", "adapters_pt_500k", "adapters_pt"])

handles, labels = ax.get_legend_handles_labels()
print(labels)
order = [1, 0]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order])
# Out:
# ['adapt_zbert_reduc_16', 'adapt_zsbert_reduc_16']
